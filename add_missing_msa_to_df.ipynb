# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
def date_to_datetime(data):
    data['DATE']= pd.to_datetime(data.DATE, format='%d/%m/%Y')
    data['DATE'] = data['DATE'].dt.date
    return data

# %%
unemployment_data= pd.read_csv("datasets/unemployment_data.csv", index_col=0)
unemployment_data = date_to_datetime(unemployment_data)
bpunemp= pd.read_csv("datasets/bpunemp.csv")

civilian_data= pd.read_csv("datasets/civilian_data.csv", index_col=0)
bpclf= pd.read_csv("datasets/bpclf.csv")

personal_income_data= pd.read_csv("datasets/personal income_data.csv", index_col=0)
lvRPI= pd.read_csv("datasets/lvRPI.csv")
bpRPI= pd.read_csv("datasets/bpRPI.csv")

# %%
def set_data(data):
    dates = data['DATE']
    dates = [dates[i].replace("-", "/") for i in range(0,len(dates))]
    dates = [f'{i.split("/")[2]}/{i.split("/")[1]}/{i.split("/")[0]}' for i in dates]
    data['DATE'] = dates
    data_df = date_to_datetime(data)
    return data_df

# %%
bpunemp = set_data(bpunemp)
bpunemp.rename(columns={ bpunemp.columns[1]: "Unemployment_Rate" }, inplace = True)
bpunemp['MSA']='Bridgeport-Stamford-Norwalk'
bpunemp['State']='CT'
bpunemp['1_Month_change']=bpunemp['Unemployment_Rate'].pct_change()
bpunemp['1_Year_change']=bpunemp['Unemployment_Rate'].pct_change(periods=12)

# %%
unemployment_data
# Out:
#               DATE  Unemployment_Rate                     MSA State  \
# 0       1990-01-01                5.2  Denver-Aurora-Lakewood    CO
# 1       1990-02-01                5.1  Denver-Aurora-Lakewood    CO
# 2       1990-03-01                5.0  Denver-Aurora-Lakewood    CO
# 3       1990-04-01                4.6  Denver-Aurora-Lakewood    CO
# 4       1990-05-01                4.3  Denver-Aurora-Lakewood    CO
# ...            ...                ...                     ...   ...
# 132362  2020-09-01                6.4             Walla Walla    WA
# 132363  2020-10-01                4.6             Walla Walla    WA
# 132364  2020-11-01                5.2             Walla Walla    WA
# 132365  2020-12-01                6.5             Walla Walla    WA
# 132366  2021-01-01                6.0             Walla Walla    WA
#
#         1_Month_change  1_Year_change
# 0                  NaN            NaN
# 1            -0.019231            NaN
# 2            -0.019608            NaN
# 3            -0.080000            NaN
# 4            -0.065217            NaN
# ...                ...            ...
# 132362       -0.072464       0.600000
# 132363       -0.281250       0.179487
# 132364        0.130435       0.238095
# 132365        0.250000       0.354167
# 132366       -0.076923       0.111111
#
# [132367 rows x 6 columns]

# %%
bpunemp
# Out:
#            DATE  Unemployment_Rate                          MSA State  \
# 0    1990-01-01                4.7  Bridgeport-Stamford-Norwalk    CT
# 1    1990-02-01                4.7  Bridgeport-Stamford-Norwalk    CT
# 2    1990-03-01                4.4  Bridgeport-Stamford-Norwalk    CT
# 3    1990-04-01                4.4  Bridgeport-Stamford-Norwalk    CT
# 4    1990-05-01                4.4  Bridgeport-Stamford-Norwalk    CT
# ..          ...                ...                          ...   ...
# 368  2020-09-01                7.9  Bridgeport-Stamford-Norwalk    CT
# 369  2020-10-01                6.1  Bridgeport-Stamford-Norwalk    CT
# 370  2020-11-01                8.0  Bridgeport-Stamford-Norwalk    CT
# 371  2020-12-01                7.6  Bridgeport-Stamford-Norwalk    CT
# 372  2021-01-01                8.7  Bridgeport-Stamford-Norwalk    CT
#
#      1_Month_change  1_Year_change
# 0               NaN            NaN
# 1          0.000000            NaN
# 2         -0.063830            NaN
# 3          0.000000            NaN
# 4          0.000000            NaN
# ..              ...            ...
# 368       -0.070588       1.257143
# 369       -0.227848       0.742857
# 370        0.311475       1.424242
# 371       -0.050000       1.375000
# 372        0.144737       0.933333
#
# [373 rows x 6 columns]

# %%
unemployment_data_new = pd.concat([unemployment_data,bpunemp])
unemployment_data_new = unemployment_data_new.reset_index()
unemployment_data_new = unemployment_data_new.drop(columns=['index'])
unemployment_data_new.to_csv("unemployment_data_new.csv")
unemployment_data_new
# Out:
#               DATE  Unemployment_Rate                          MSA State  \
# 0       1990-01-01                5.2       Denver-Aurora-Lakewood    CO
# 1       1990-02-01                5.1       Denver-Aurora-Lakewood    CO
# 2       1990-03-01                5.0       Denver-Aurora-Lakewood    CO
# 3       1990-04-01                4.6       Denver-Aurora-Lakewood    CO
# 4       1990-05-01                4.3       Denver-Aurora-Lakewood    CO
# ...            ...                ...                          ...   ...
# 132735  2020-09-01                7.9  Bridgeport-Stamford-Norwalk    CT
# 132736  2020-10-01                6.1  Bridgeport-Stamford-Norwalk    CT
# 132737  2020-11-01                8.0  Bridgeport-Stamford-Norwalk    CT
# 132738  2020-12-01                7.6  Bridgeport-Stamford-Norwalk    CT
# 132739  2021-01-01                8.7  Bridgeport-Stamford-Norwalk    CT
#
#         1_Month_change  1_Year_change
# 0                  NaN            NaN
# 1            -0.019231            NaN
# 2            -0.019608            NaN
# 3            -0.080000            NaN
# 4            -0.065217            NaN
# ...                ...            ...
# 132735       -0.070588       1.257143
# 132736       -0.227848       0.742857
# 132737        0.311475       1.424242
# 132738       -0.050000       1.375000
# 132739        0.144737       0.933333
#
# [132740 rows x 6 columns]

# %%
bpclf = set_data(bpclf)
bpclf.rename(columns={ bpclf.columns[1]: "civilian" }, inplace = True)
bpclf['MSA']='Bridgeport-Stamford-Norwalk'
bpclf['State']='CT'
bpclf['1_Month_change']=bpclf['civilian'].pct_change()
bpclf['1_Year_change']=bpclf['civilian'].pct_change(periods=12)

# %%
civilian_data
# Out:
#               DATE  civilian         MSA     State  1_Month_change  \
# 0       1990-01-01   36147.0   Manhattan        KS             NaN
# 1       1990-02-01   36617.0   Manhattan        KS        0.013002
# 2       1990-03-01   36593.0   Manhattan        KS       -0.000655
# 3       1990-04-01   36632.0   Manhattan        KS        0.001066
# 4       1990-05-01   36731.0   Manhattan        KS        0.002703
# ...            ...       ...         ...       ...             ...
# 118471  2014-08-01      36.0  Palm Coast  FL (MSA)       -0.005525
# 118472  2014-09-01      36.1  Palm Coast  FL (MSA)        0.002778
# 118473  2014-10-01      35.8  Palm Coast  FL (MSA)       -0.008310
# 118474  2014-11-01      35.4  Palm Coast  FL (MSA)       -0.011173
# 118475  2014-12-01      35.1  Palm Coast  FL (MSA)       -0.008475
#
#         1_Year_change
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 118471       0.025641
# 118472       0.019774
# 118473       0.019943
# 118474       0.017241
# 118475       0.020349
#
# [118476 rows x 6 columns]

# %%
bpclf
# Out:
#            DATE  civilian                          MSA State  1_Month_change  \
# 0    1990-01-01    447651  Bridgeport-Stamford-Norwalk    CT             NaN
# 1    1990-02-01    445485  Bridgeport-Stamford-Norwalk    CT       -0.004839
# 2    1990-03-01    448711  Bridgeport-Stamford-Norwalk    CT        0.007242
# 3    1990-04-01    448742  Bridgeport-Stamford-Norwalk    CT        0.000069
# 4    1990-05-01    452856  Bridgeport-Stamford-Norwalk    CT        0.009168
# ..          ...       ...                          ...   ...             ...
# 368  2020-09-01    453494  Bridgeport-Stamford-Norwalk    CT        0.007498
# 369  2020-10-01    442180  Bridgeport-Stamford-Norwalk    CT       -0.024949
# 370  2020-11-01    452116  Bridgeport-Stamford-Norwalk    CT        0.022470
# 371  2020-12-01    446116  Bridgeport-Stamford-Norwalk    CT       -0.013271
# 372  2021-01-01    438437  Bridgeport-Stamford-Norwalk    CT       -0.017213
#
#      1_Year_change
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 368      -0.025622
# 369      -0.054482
# 370      -0.037840
# 371      -0.046761
# 372      -0.063105
#
# [373 rows x 6 columns]

# %%
civilian_data_new = pd.concat([civilian_data,bpclf])
civilian_data_new = civilian_data_new.reset_index()
civilian_data_new = civilian_data_new.drop(columns=['index'])
civilian_data_new.to_csv("civilian_data_new.csv")
civilian_data_new
# Out:
#               DATE  civilian                          MSA State  \
# 0       1990-01-01   36147.0                    Manhattan    KS
# 1       1990-02-01   36617.0                    Manhattan    KS
# 2       1990-03-01   36593.0                    Manhattan    KS
# 3       1990-04-01   36632.0                    Manhattan    KS
# 4       1990-05-01   36731.0                    Manhattan    KS
# ...            ...       ...                          ...   ...
# 118844  2020-09-01  453494.0  Bridgeport-Stamford-Norwalk    CT
# 118845  2020-10-01  442180.0  Bridgeport-Stamford-Norwalk    CT
# 118846  2020-11-01  452116.0  Bridgeport-Stamford-Norwalk    CT
# 118847  2020-12-01  446116.0  Bridgeport-Stamford-Norwalk    CT
# 118848  2021-01-01  438437.0  Bridgeport-Stamford-Norwalk    CT
#
#         1_Month_change  1_Year_change
# 0                  NaN            NaN
# 1             0.013002            NaN
# 2            -0.000655            NaN
# 3             0.001066            NaN
# 4             0.002703            NaN
# ...                ...            ...
# 118844        0.007498      -0.025622
# 118845       -0.024949      -0.054482
# 118846        0.022470      -0.037840
# 118847       -0.013271      -0.046761
# 118848       -0.017213      -0.063105
#
# [118849 rows x 6 columns]

# %%
bpRPI = set_data(bpRPI)
bpRPI.rename(columns={ bpRPI.columns[1]: "personal income" }, inplace = True)
bpRPI['MSA']='Bridgeport-Stamford-Norwalk'
bpRPI['State']='CT'
bpRPI['1_Year_change']=bpRPI['personal income'].pct_change(periods=12)

lvRPI = set_data(lvRPI)
lvRPI.rename(columns={ lvRPI.columns[1]: "personal income" }, inplace = True)
lvRPI['MSA']='Las Vegas-Henderson-Paradise'
lvRPI['State']='CT'
lvRPI['1_Year_change']=lvRPI['personal income'].pct_change(periods=12)

# %%
personal_income_data
# Out:
#             DATE  personal income                        MSA State  \
# 0     2008-01-01            35997  Orlando-Kissimmee-Sanford    FL
# 1     2009-01-01            33992  Orlando-Kissimmee-Sanford    FL
# 2     2010-01-01            35220  Orlando-Kissimmee-Sanford    FL
# 3     2011-01-01            35996  Orlando-Kissimmee-Sanford    FL
# 4     2012-01-01            36195  Orlando-Kissimmee-Sanford    FL
# ...          ...              ...                        ...   ...
# 3723  2015-01-01            40521                  El Centro    CA
# 3724  2016-01-01            38857                  El Centro    CA
# 3725  2017-01-01            38516                  El Centro    CA
# 3726  2018-01-01            38555                  El Centro    CA
# 3727  2019-01-01            41090                  El Centro    CA
#
#       1_Year_change
# 0               NaN
# 1         -0.055699
# 2          0.036126
# 3          0.022033
# 4          0.005528
# ...             ...
# 3723       0.078145
# 3724      -0.041065
# 3725      -0.008776
# 3726       0.001013
# 3727       0.065750
#
# [3728 rows x 5 columns]

# %%
bpRPI
# Out:
#           DATE  personal income                          MSA State  \
# 0   2008-01-01         78252116  Bridgeport-Stamford-Norwalk    CT
# 1   2009-01-01         77980295  Bridgeport-Stamford-Norwalk    CT
# 2   2010-01-01         82417875  Bridgeport-Stamford-Norwalk    CT
# 3   2011-01-01         81697325  Bridgeport-Stamford-Norwalk    CT
# 4   2012-01-01         80792377  Bridgeport-Stamford-Norwalk    CT
# 5   2013-01-01         75734359  Bridgeport-Stamford-Norwalk    CT
# 6   2014-01-01         79568160  Bridgeport-Stamford-Norwalk    CT
# 7   2015-01-01         81198652  Bridgeport-Stamford-Norwalk    CT
# 8   2016-01-01         84358889  Bridgeport-Stamford-Norwalk    CT
# 9   2017-01-01         87600009  Bridgeport-Stamford-Norwalk    CT
# 10  2018-01-01         91221869  Bridgeport-Stamford-Norwalk    CT
# 11  2019-01-01         93548505  Bridgeport-Stamford-Norwalk    CT
#
#     1_Year_change
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN

# %%
lvRPI
# Out:
#           DATE  personal income                           MSA State  \
# 0   2008-01-01         77439727  Las Vegas-Henderson-Paradise    CT
# 1   2009-01-01         70972661  Las Vegas-Henderson-Paradise    CT
# 2   2010-01-01         72061590  Las Vegas-Henderson-Paradise    CT
# 3   2011-01-01         73512615  Las Vegas-Henderson-Paradise    CT
# 4   2012-01-01         77727213  Las Vegas-Henderson-Paradise    CT
# 5   2013-01-01         76666749  Las Vegas-Henderson-Paradise    CT
# 6   2014-01-01         82544976  Las Vegas-Henderson-Paradise    CT
# 7   2015-01-01         89924069  Las Vegas-Henderson-Paradise    CT
# 8   2016-01-01         94329262  Las Vegas-Henderson-Paradise    CT
# 9   2017-01-01         99232325  Las Vegas-Henderson-Paradise    CT
# 10  2018-01-01        103018673  Las Vegas-Henderson-Paradise    CT
# 11  2019-01-01        104888357  Las Vegas-Henderson-Paradise    CT
#
#     1_Year_change
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN

# %%
personal_income_data_new = pd.concat([personal_income_data,lvRPI,bpRPI])
personal_income_data_new = personal_income_data_new.reset_index()
personal_income_data_new = personal_income_data_new.drop(columns=['index'])
personal_income_data_new.to_csv("personal_income_data_new.csv")
personal_income_data_new
# Out:
#             DATE  personal income                          MSA State  \
# 0     2008-01-01            35997    Orlando-Kissimmee-Sanford    FL
# 1     2009-01-01            33992    Orlando-Kissimmee-Sanford    FL
# 2     2010-01-01            35220    Orlando-Kissimmee-Sanford    FL
# 3     2011-01-01            35996    Orlando-Kissimmee-Sanford    FL
# 4     2012-01-01            36195    Orlando-Kissimmee-Sanford    FL
# ...          ...              ...                          ...   ...
# 3747  2015-01-01         81198652  Bridgeport-Stamford-Norwalk    CT
# 3748  2016-01-01         84358889  Bridgeport-Stamford-Norwalk    CT
# 3749  2017-01-01         87600009  Bridgeport-Stamford-Norwalk    CT
# 3750  2018-01-01         91221869  Bridgeport-Stamford-Norwalk    CT
# 3751  2019-01-01         93548505  Bridgeport-Stamford-Norwalk    CT
#
#       1_Year_change
# 0               NaN
# 1         -0.055699
# 2          0.036126
# 3          0.022033
# 4          0.005528
# ...             ...
# 3747            NaN
# 3748            NaN
# 3749            NaN
# 3750            NaN
# 3751            NaN
#
# [3752 rows x 5 columns]
